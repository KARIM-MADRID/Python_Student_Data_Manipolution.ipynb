# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\ibast\Downloads\Students data.csv")

# %%
df.head()
# Out:
#      ID class  gender  race    GPA  Algebra  Calculus1  Calculus2  Statistics  \
# 0  1141     A    male     1  73.47       64         81         87          60
# 1  1142     A  female     1  71.22       57         50         51          51
# 2  1143     A  female     2  74.56       47         48         71          60
# 3  1144     A  female     1  72.89       46         72         38          60
# 4  1145     A  female     1  70.11       49         45         63          60
#
#    Probability  Measure  Functional_analysis from1 from2 from3  from4  y
# 0           74       71                   60     A     A     A      3  0
# 1           55       62                   61     B     A     A      2  0
# 2           61       68                   64     C     A     A      0  1
# 3           29       54                   51     D     A     A      0  0
# 4           66       66                   61     E     A     A      0  0

# %%
df.tail()
# Out:
#        ID class  gender  race    GPA  Algebra  Calculus1  Calculus2  \
# 100  1241     A  female     1  88.34       87         83         92
# 101  1242     B    male     1  89.84       98         77         95
# 102  1243     B    male     1  88.82       83         80         91
# 103  1244     A    male     1  86.60       92         82         91
# 104  1245     A    male     1  93.71       93         97         99
#
#      Statistics  Probability  Measure  Functional_analysis from1 from2 from3  \
# 100          98           93       86                   90     M     B     A
# 101          98           96       88                  100     A     B     A
# 102          98           93       95                   71     T     B     A
# 103          99           94       82                   78     S     B     A
# 104         100           97       90                   90     K     B     A
#
#      from4  y
# 100      0  1
# 101      0  1
# 102      0  2
# 103      0  2
# 104      0  2

# %%
df.columns
# Out:
# Index(['ID', 'class', 'gender', 'race', 'GPA', 'Algebra', 'Calculus1',
#        'Calculus2', 'Statistics', 'Probability', 'Measure',
#        'Functional_analysis', 'from1', 'from2', 'from3', 'from4', 'y'],
#       dtype='object')

# %%
df.shape
# Out:
# (105, 17)

# %%
df[5:11]
# Out:
#       ID class  gender  race    GPA  Algebra  Calculus1  Calculus2  \
# 5   1146     A    male     3  65.04       60         60         39
# 6   1147     A    male     4  77.11       60         43         52
# 7   1148     A  female     5  64.75       60         38         60
# 8   1149     B  female     5  77.92       61         60         66
# 9   1150     A  female     5  76.50       60         61         60
# 10  1151     A    male     1  76.83       61         66         61
#
#     Statistics  Probability  Measure  Functional_analysis from1 from2 from3  \
# 5           61           65       74                   60     F     B     C
# 6           63           71       72                   75     G     A     A
# 7           63           70       68                   51     H     B     C
# 8           68           80       78                   71     I     B     A
# 9           69           73       60                   62     H     B     A
# ...

# %%
df[df.GPA>70]
# Out:
#        ID class  gender  race    GPA  Algebra  Calculus1  Calculus2  \
# 0    1141     A    male     1  73.47       64         81         87
# 1    1142     A  female     1  71.22       57         50         51
# 2    1143     A  female     2  74.56       47         48         71
# 3    1144     A  female     1  72.89       46         72         38
# 4    1145     A  female     1  70.11       49         45         63
# ..    ...   ...     ...   ...    ...      ...        ...        ...
# 100  1241     A  female     1  88.34       87         83         92
# 101  1242     B    male     1  89.84       98         77         95
# 102  1243     B    male     1  88.82       83         80         91
# 103  1244     A    male     1  86.60       92         82         91
# 104  1245     A    male     1  93.71       93         97         99
#
#      Statistics  Probability  Measure  Functional_analysis from1 from2 from3  \
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of        ID class  gender  race    GPA  Algebra  Calculus1  Calculus2  \
# 0    1141     A    male     1  73.47       64         81         87
# 1    1142     A  female     1  71.22       57         50         51
# 2    1143     A  female     2  74.56       47         48         71
# 3    1144     A  female     1  72.89       46         72         38
# 4    1145     A  female     1  70.11       49         45         63
# ..    ...   ...     ...   ...    ...      ...        ...        ...
# 100  1241     A  female     1  88.34       87         83         92
# 101  1242     B    male     1  89.84       98         77         95
# 102  1243     B    male     1  88.82       83         80         91
# 103  1244     A    male     1  86.60       92         82         91
# 104  1245     A    male     1  93.71       93         97         99
#
#      Statistics  Probability  Measure  Functional_analysis from1 from2 from3  \
# ...

# %%
df["GPA"].std()
# Out:
# 6.053186529520808

# %%
df["GPA"].mean()
# Out:
# 82.95704761904763

# %%
df["GPA"].max()
# Out:
# 93.71

# %%
df.median()
# Out:
# C:\Users\ibast\AppData\Local\Temp/ipykernel_51208/530051474.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.median()
# ID                     1193.00
# race                      1.00
# GPA                      84.11
# Algebra                  76.00
# Calculus1                73.00
# Calculus2                83.00
# Statistics               87.00
# Probability              85.00
# Measure                  81.00
# Functional_analysis      76.00
# from4                     0.00
# y                         0.00
# dtype: float64

# %%
import matplotlib
# %matplotlib inline

# %%
student = df['GPA']
student.hist(bins=5)
# Out:
# <AxesSubplot:>

# %%
df.plot()
# Out:
# <AxesSubplot:>
